# %% [markdown]
# # Multiclass prediction
#
# In this notebook I'm gonna show the process to create a prediction of a music_genre.

# %% [markdown]
# ## Imports

# %%
# %matplotlib inline

# %%
#pip install scikit-plot

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in ./opt/anaconda3/lib/python3.9/site-packages (1.7.1)
# Requirement already satisfied: numpy in ./opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.21.5)
# Requirement already satisfied: scipy in ./opt/anaconda3/lib/python3.9/site-packages (from xgboost) (1.9.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.preprocessing import LabelEncoder # LabelEncoder is a utility class to help normalize labels such that they contain only values between 0 and n_classes-1. 
from sklearn.preprocessing import StandardScaler # Make all values in all variables within the same range.
from sklearn.model_selection import train_test_split, cross_val_score #Split arrays or matrices into random train and test subsets.
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import make_scorer, f1_score, accuracy_score, confusion_matrix, classification_report,precision_score,classification_report, precision_recall_curve
from sklearn.metrics import roc_curve, roc_auc_score
import scikitplot as skplt

# %% [markdown]
# ## Load data

# %%
music = pd.read_csv("/Users/andrescarvajal/Desktop/Data Science/music_genre.csv")

# %%
music.head()
# Out:
#    instance_id           artist_name            track_name  popularity  \
# 0      32894.0              Röyksopp  Röyksopp's Night Out        27.0
# 1      46652.0  Thievery Corporation      The Shining Path        31.0
# 2      30097.0        Dillon Francis             Hurricane        28.0
# 3      62177.0              Dubloadz                 Nitro        34.0
# 4      24907.0           What So Not      Divide & Conquer        32.0
#
#    acousticness  danceability  duration_ms  energy  instrumentalness key  \
# 0       0.00468         0.652         -1.0   0.941           0.79200  A#
# 1       0.01270         0.622     218293.0   0.890           0.95000   D
# 2       0.00306         0.620     215613.0   0.755           0.01180  G#
# 3       0.02540         0.774     166875.0   0.700           0.00253  C#
# 4       0.00465         0.638     222369.0   0.587           0.90900  F#
#
#    liveness  loudness   mode  speechiness               tempo obtained_date  \
# 0     0.115    -5.201  Minor       0.0748             100.889         4-Apr
# 1     0.124    -7.043  Minor       0.0300  115.00200000000001         4-Apr
# 2     0.534    -4.617  Major       0.0345             127.994         4-Apr
# 3     0.157    -4.498  Major       0.2390             128.014         4-Apr
# 4     0.157    -6.266  Major       0.0413             145.036         4-Apr
#
#    valence music_genre
# 0    0.759  Electronic
# 1    0.531  Electronic
# 2    0.333  Electronic
# 3    0.270  Electronic
# 4    0.323  Electronic

# %% [markdown]
# ## Exploring and cleaning the data

# %%
music.shape
#The data set has 50005 entries described with 18 features.
# Out:
# (50005, 18)

# %%
music.duplicated() # Just using duplicated it is not easy to see if there is any duplicated entry.
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 50000    False
# 50001    False
# 50002    False
# 50003    False
# 50004    False
# Length: 50005, dtype: bool

# %% [markdown]
# ### Remove duplicates

# %%
music.duplicated().any() # duplicated() returns a bool if the entry is duplicated, any() method returns true if find any true over the iterable object.
# Out:
# True

# %%
duplicated = music.duplicated() #Storing duplicated entries, will be a Series Object 
print(duplicated)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 50000    False
# 50001    False
# 50002    False
# 50003    False
# 50004    False
# Length: 50005, dtype: bool

# %%
music[duplicated]
# Out:
#        instance_id artist_name track_name  popularity  acousticness  \
# 10001          NaN         NaN        NaN         NaN           NaN
# 10002          NaN         NaN        NaN         NaN           NaN
# 10003          NaN         NaN        NaN         NaN           NaN
# 10004          NaN         NaN        NaN         NaN           NaN
#
#        danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 10001           NaN          NaN     NaN               NaN  NaN       NaN
# 10002           NaN          NaN     NaN               NaN  NaN       NaN
# 10003           NaN          NaN     NaN               NaN  NaN       NaN
# 10004           NaN          NaN     NaN               NaN  NaN       NaN
#
#        loudness mode  speechiness tempo obtained_date  valence music_genre
# 10001       NaN  NaN          NaN   NaN           NaN      NaN         NaN
# 10002       NaN  NaN          NaN   NaN           NaN      NaN         NaN
# 10003       NaN  NaN          NaN   NaN           NaN      NaN         NaN
# 10004       NaN  NaN          NaN   NaN           NaN      NaN         NaN

# %%
music.iloc[9999:10006] #There are 5 continues entries all of them with not only repeated but with NaN into all the fields.
# Out:
#        instance_id artist_name                     track_name  popularity  \
# 9999       41509.0  Hachioji P           Yeah! Yeah!! Yeah!!!        14.0
# 10000          NaN         NaN                            NaN         NaN
# 10001          NaN         NaN                            NaN         NaN
# 10002          NaN         NaN                            NaN         NaN
# 10003          NaN         NaN                            NaN         NaN
# 10004          NaN         NaN                            NaN         NaN
# 10005      77089.0   Blockhead  Cheer up, You're Not Dead Yet        44.0
#
#        acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 9999        0.02000         0.573     226374.0   0.921          0.000004   F#
# 10000           NaN           NaN          NaN     NaN               NaN  NaN
# 10001           NaN           NaN          NaN     NaN               NaN  NaN
# 10002           NaN           NaN          NaN     NaN               NaN  NaN
# 10003           NaN           NaN          NaN     NaN               NaN  NaN
# 10004           NaN           NaN          NaN     NaN               NaN  NaN
# 10005       0.00621         0.711     285987.0   0.621          0.029700    G
#
#        liveness  loudness   mode  speechiness    tempo obtained_date  valence  \
# 9999      0.325    -3.841  Major       0.0734  135.029         4-Apr    0.599
# 10000       NaN       NaN    NaN          NaN      NaN           NaN      NaN
# 10001       NaN       NaN    NaN          NaN      NaN           NaN      NaN
# 10002       NaN       NaN    NaN          NaN      NaN           NaN      NaN
# 10003       NaN       NaN    NaN          NaN      NaN           NaN      NaN
# 10004       NaN       NaN    NaN          NaN      NaN           NaN      NaN
# 10005     0.159    -7.429  Major       0.0382  142.065         4-Apr    0.607
#
#       music_genre
# 9999        Anime
# 10000         NaN
# 10001         NaN
# 10002         NaN
# 10003         NaN
# 10004         NaN
# 10005        Jazz

# %%
music.drop([10000, 10001, 10002, 10003, 10004], inplace = True)

# %%
music[duplicated] # When you pass indexing a Data Frame with a Boolean Series it match the True results.
# Out:
# /var/folders/pd/gd_w9jbx5hb006vr17f17dmw0000gn/T/ipykernel_37476/294012141.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   music[duplicated] # When you pass indexing a Data Frame with a Boolean Series it match the True results.
# Empty DataFrame
# Columns: [instance_id, artist_name, track_name, popularity, acousticness, danceability, duration_ms, energy, instrumentalness, key, liveness, loudness, mode, speechiness, tempo, obtained_date, valence, music_genre]
# Index: []

# %%
music.shape # Now the Data Frame has
# Out:
# (50000, 18)

# %%
music.reset_index(inplace = True) #The dataset index was reset since 5 rows were removed earlier.

# %% [markdown]
# ### Handling high entropy
#
# Entropy is a measure of chaos in a system. Because it is much more dynamic than other more rigid metrics like accuracy or even mean squared error. It appears everywhere in machine learning!
#
# Similar values in a feature suggest low entropy, and diverse - high entropy. The higher entropy, the less predictive properties this feature has.

# %%
len(music["instance_id"].unique()) #instance_id holds information about a song's ID. These are unique for each sample, thus will not used for modelling.
# Out:
# 50000

# %%
len(music["artist_name"].unique()) # artist_name holds information about the singers' name. The dataset contains information about 6863 artists.
# Out:
# 6863

# %%
music["key"].unique() # key holds information about the tone used in each sounds.
# Out:
# array(['A#', 'D', 'G#', 'C#', 'F#', 'B', 'G', 'F', 'A', 'C', 'E', 'D#'],
#       dtype=object)

# %%
music["mode"].unique() # There are two classes in western music, Major and Minor.
# Out:
# array(['Minor', 'Major'], dtype=object)

# %%
music["obtained_date"].unique() #It is not clear what information brings, will be remove.
# Out:
# array(['4-Apr', '3-Apr', '5-Apr', '1-Apr', '0/4'], dtype=object)

# %%
music["music_genre"].unique() # music_genre is the target column, that we are trying to predict.
# Out:
# array(['Electronic', 'Anime', 'Jazz', 'Alternative', 'Country', 'Rap',
#        'Blues', 'Rock', 'Classical', 'Hip-Hop'], dtype=object)

# %%
#Non-predictive feature will be remove it.
music = music.drop(["index", "instance_id", "track_name", "obtained_date"], axis = 1) # .drop() removes the index or column, axis = 1 correspond to columns
# New Data Frame
music.head()
# Out:
#             artist_name  popularity  acousticness  danceability  duration_ms  \
# 0              Röyksopp        27.0       0.00468         0.652         -1.0
# 1  Thievery Corporation        31.0       0.01270         0.622     218293.0
# 2        Dillon Francis        28.0       0.00306         0.620     215613.0
# 3              Dubloadz        34.0       0.02540         0.774     166875.0
# 4           What So Not        32.0       0.00465         0.638     222369.0
#
#    energy  instrumentalness key  liveness  loudness   mode  speechiness  \
# 0   0.941           0.79200  A#     0.115    -5.201  Minor       0.0748
# 1   0.890           0.95000   D     0.124    -7.043  Minor       0.0300
# 2   0.755           0.01180  G#     0.534    -4.617  Major       0.0345
# 3   0.700           0.00253  C#     0.157    -4.498  Major       0.2390
# 4   0.587           0.90900  F#     0.157    -6.266  Major       0.0413
#
#                 tempo  valence music_genre
# 0             100.889    0.759  Electronic
# 1  115.00200000000001    0.531  Electronic
# 2             127.994    0.333  Electronic
# 3             128.014    0.270  Electronic
# 4             145.036    0.323  Electronic

# %% [markdown]
# ### Exploring music["artist_name"]

# %%
artists = music["artist_name"].value_counts()[:10].sort_values(ascending = True)
# .value_counts() returns a series object that contains the frecuency of a value, each one will be the index label .sort_values(ascending = True) sort from the lowest to the higest value

# %%
artists
# Out:
# Eminem                      147
# Yuki Hayashi                167
# Capcom Sound Team           169
# Drake                       172
# Frédéric Chopin             241
# Johann Sebastian Bach       314
# Ludwig van Beethoven        317
# Wolfgang Amadeus Mozart     402
# Nobuo Uematsu               429
# empty_field                2489
# Name: artist_name, dtype: int64

# %%
music[music["artist_name"] == "empty_field"]
# Out:
#        artist_name  popularity  acousticness  danceability  duration_ms  \
# 19     empty_field        50.0       0.02810         0.656     307328.0
# 25     empty_field        34.0       0.02360         0.715     221050.0
# 44     empty_field        31.0       0.00350         0.595     222147.0
# 128    empty_field        32.0       0.01390         0.498         -1.0
# 135    empty_field        44.0       0.15300         0.792     265133.0
# ...            ...         ...           ...           ...          ...
# 49937  empty_field        50.0       0.05480         0.754     132414.0
# 49951  empty_field        52.0       0.13300         0.867         -1.0
# 49966  empty_field        51.0       0.12400         0.786     187027.0
# 49986  empty_field        53.0       0.00392         0.770     211820.0
# 49989  empty_field        62.0       0.01060         0.944     197923.0
#
#        energy  instrumentalness key  liveness  loudness   mode  speechiness  \
# 19      0.653          0.858000  F#    0.1120   -11.883  Minor       0.0396
# 25      0.978          0.000493   D    0.2160    -1.538  Major       0.3620
# 44      0.904          0.003780   D    0.0533    -6.805  Minor       0.0349
# 128     0.945          0.647000   F    0.3380    -0.003  Minor       0.1370
# 135     0.549          0.379000   F    0.3430    -9.855  Major       0.0456
# ...       ...               ...  ..       ...       ...    ...          ...
# 49937   0.840          0.000014   A    0.1500    -5.111  Major       0.3130
# 49951   0.618          0.000002   B    0.1280    -4.956  Minor       0.0614
# 49966   0.738          0.000000   C    0.1400    -5.621  Major       0.3890
# 49986   0.905          0.000003   F    0.1690    -8.235  Minor       0.1440
# 49989   0.559          0.000033   B    0.0775    -7.706  Minor       0.0640
#
#                     tempo  valence music_genre
# 19                117.999   0.1990  Electronic
# 25                125.109   0.4180  Electronic
# 44                 127.61   0.8410  Electronic
# 128               149.888   0.1790  Electronic
# 135    120.01299999999999   0.4760  Electronic
# ...                   ...      ...         ...
# 49937             144.991   0.0397     Hip-Hop
# 49951             140.005   0.8570     Hip-Hop
# 49966              93.758   0.7800     Hip-Hop
# 49986             135.999   0.4640     Hip-Hop
# 49989             107.992   0.7050     Hip-Hop
#
# [2489 rows x 15 columns]

# %%
artists.index
# Out:
# Index(['Eminem', 'Yuki Hayashi', 'Capcom Sound Team', 'Drake',
#        'Frédéric Chopin', 'Johann Sebastian Bach', 'Ludwig van Beethoven',
#        'Wolfgang Amadeus Mozart', 'Nobuo Uematsu', 'empty_field'],
#       dtype='object')

# %%
plt.barh(artists.index, artists) #Create a horizontal bar matplotlib graph
plt.xlabel("Number of songs per artist")
plt.title("Songs per artist")
plt.show() #Display matplotlib plot

# %%
# Now I´m gonna remove all the entries with music["artis_name"] == "empty_field" using the index as a parameter for drop pandas method
#music = music.drop(music[music["artist_name"] == "empty_field"].index)
#Display top 10 artist
top_10_artists = music["artist_name"].value_counts()[:10].sort_values(ascending = True)
plt.barh(top_10_artists.index, top_10_artists)
plt.xlabel("Number of songs per artist")
plt.title("Songs per artist")
plt.show()

# %%
# The last step will be remove artist_name to reduce the feature's number and because by itself the name does not provide a valious information.
music.drop("artist_name", axis = 1, inplace = True) # inplace = True returns none and make the operation inplace.

# %%
music.head()
#Most of the data are numerical values, just 3 columns are categorical data "key","mode" and "music_genre".
# Out:
#    popularity  acousticness  danceability  duration_ms  energy  \
# 0        27.0       0.00468         0.652         -1.0   0.941
# 1        31.0       0.01270         0.622     218293.0   0.890
# 2        28.0       0.00306         0.620     215613.0   0.755
# 3        34.0       0.02540         0.774     166875.0   0.700
# 4        32.0       0.00465         0.638     222369.0   0.587
#
#    instrumentalness key  liveness  loudness   mode  speechiness  \
# 0           0.79200  A#     0.115    -5.201  Minor       0.0748
# 1           0.95000   D     0.124    -7.043  Minor       0.0300
# 2           0.01180  G#     0.534    -4.617  Major       0.0345
# 3           0.00253  C#     0.157    -4.498  Major       0.2390
# 4           0.90900  F#     0.157    -6.266  Major       0.0413
#
#                 tempo  valence music_genre
# 0             100.889    0.759  Electronic
# 1  115.00200000000001    0.531  Electronic
# 2             127.994    0.333  Electronic
# 3             128.014    0.270  Electronic
# 4             145.036    0.323  Electronic

# %% [markdown]
# ## Data Visualization

# %%
categorical_columns = ["key","mode","music_genre"] # list with categorical columns.

def plot_counts(feature, order = None):
    plt.figure(figsize = (9, 3))# Width and Height in inches
    sns.countplot(x = feature, data = music, palette = "flare", order = order) # Show the coynts of observations in each categorical bin using bars.
    plt.title(f"Counts in each {feature}")
    
for feature in music.columns:
    if feature in categorical_columns:
        plot_counts(feature)
        plt.show()

# %% [markdown]
# ### Histograms

# %%
music.dtypes
# The most of columns are float64, to display numerical distributions it has to be a numerical valua, "tempo" has object type so I´m gonna explore it.
# Out:
# popularity          float64
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# key                  object
# liveness            float64
# loudness            float64
# mode                 object
# speechiness         float64
# tempo                object
# valence             float64
# music_genre          object
# dtype: object

# %%
music['tempo'].head()
# Out:
# 0               100.889
# 1    115.00200000000001
# 2               127.994
# 3               128.014
# 4               145.036
# Name: tempo, dtype: object

# %%
music["tempo"].unique()
# Out:
# array(['100.889', '115.00200000000001', '127.994', ..., '112.97',
#        '167.655', '99.20100000000001'], dtype=object)

# %%
# Check wwhat is the string value that is hidden inside de column and is no a float instance
for i in range(len(music)):
    try:
        if isinstance(float(music.iloc[i]['tempo']),float):
            continue
    except:
        print(music.iloc[i]['tempo'])
# Out:
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?
# ?

# %%
music[music["tempo"] == "?"]
# Out:
#        popularity  acousticness  danceability  duration_ms  energy  \
# 5            47.0       0.00523         0.755     519468.0   0.731
# 32           45.0       0.02330         0.729     274286.0   0.869
# 35           33.0       0.10800         0.493         -1.0   0.682
# 36           45.0       0.04780         0.646     253333.0   0.649
# 39           37.0       0.20300         0.769     429941.0   0.551
# ...           ...           ...           ...          ...     ...
# 49913        58.0       0.29600         0.379     292520.0   0.644
# 49959        59.0       0.08470         0.929     215200.0   0.737
# 49962        62.0       0.17900         0.860     233293.0   0.625
# 49971        52.0       0.70000         0.462     225067.0   0.741
# 49972        58.0       0.10500         0.905     240627.0   0.414
#
#        instrumentalness key  liveness  loudness   mode  speechiness tempo  \
# 5              0.854000   D    0.2160   -10.517  Minor       0.0412     ?
# 32             0.585000   F    0.0944    -7.569  Minor       0.1290     ?
# 35             0.000000   A    0.1960    -5.781  Minor       0.2870     ?
# 36             0.002520   G    0.3530    -5.259  Major       0.1170     ?
# 39             0.882000  A#    0.1090   -12.520  Minor       0.0408     ?
# ...                 ...  ..       ...       ...    ...          ...   ...
# 49913          0.000000  A#    0.3130    -7.933  Minor       0.1120     ?
# 49959          0.000000  G#    0.8610    -6.424  Major       0.1020     ?
# 49962          0.000136   D    0.3000    -6.922  Major       0.1050     ?
# 49971          0.000000  A#    0.3400    -8.008  Minor       0.1620     ?
# 49972          0.000366  G#    0.0914    -8.112  Minor       0.0615     ?
#
#        valence music_genre
# 5       0.6140  Electronic
# 32      0.1380  Electronic
# 35      0.2390  Electronic
# 36      0.7270  Electronic
# 39      0.0618  Electronic
# ...        ...         ...
# 49913   0.1440     Hip-Hop
# 49959   0.8860     Hip-Hop
# 49962   0.2210     Hip-Hop
# 49971   0.5890     Hip-Hop
# 49972   0.7580     Hip-Hop
#
# [4980 rows x 14 columns]

# %%
#Remove all entries with "?"
music = music.drop(music[music["tempo"] == "?"].index)
music["tempo"] = music["tempo"].astype("float")

# %%
#Check the types
music.dtypes
#Now tempo is float64
# Out:
# popularity          float64
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# key                  object
# liveness            float64
# loudness            float64
# mode                 object
# speechiness         float64
# tempo               float64
# valence             float64
# music_genre          object
# dtype: object

# %%
#To display numerical distributions drop the categorical columns
numeric_features = music.drop(["key", "music_genre", "mode"], axis = 1)
#Numerical features
fig, axs = plt.subplots(ncols = 3, nrows = 4, figsize = (15, 15)) # Creates a sub plots
fig.delaxes(axs[3][2])# Delete a blank cell on the plot
index = 0

axs = axs.flatten()# To get a copy
for k, v in numeric_features.items():# A Python iterator object that contains two objects for each iteration, the label and the content as a Pandas Series objec
    sns.histplot(v, ax = axs[index])
    index += 1
plt.tight_layout(pad = 0.4, w_pad = 0.5, h_pad = 5.0)

# %% [markdown]
# ### Outliers

# %%
fig, axs = plt.subplots(ncols = 3, nrows = 4, figsize = (15, 15))
fig.delaxes(axs[3][2])
idx = 0
axs = axs.flatten()
for k, v in numeric_features.items():
    sns.boxplot(y = k, data = numeric_features, ax = axs[idx])
    idx += 1
plt.tight_layout(pad = 0.4, w_pad = 0.5, h_pad = 5.0)

# %% [markdown]
# ## Encoding categorical data

# %%
key_encoder = LabelEncoder() # LabelEncoder() returns Fitted label encoder. An instance itself
mode_encoder = LabelEncoder()
music_genre_encoder = LabelEncoder()

music["key"] = key_encoder.fit_transform(music["key"]) # Fit label encoder and return encoded labels.
music["mode"] = mode_encoder.fit_transform(music["mode"])
music["music_genre"] = music_genre_encoder.fit_transform(music["music_genre"])

# %%
music.head()
# Out:
#    popularity  acousticness  danceability  duration_ms  energy  \
# 0        27.0       0.00468         0.652         -1.0   0.941
# 1        31.0       0.01270         0.622     218293.0   0.890
# 2        28.0       0.00306         0.620     215613.0   0.755
# 3        34.0       0.02540         0.774     166875.0   0.700
# 4        32.0       0.00465         0.638     222369.0   0.587
#
#    instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 0           0.79200    1     0.115    -5.201     1       0.0748  100.889
# 1           0.95000    5     0.124    -7.043     1       0.0300  115.002
# 2           0.01180   11     0.534    -4.617     0       0.0345  127.994
# 3           0.00253    4     0.157    -4.498     0       0.2390  128.014
# 4           0.90900    9     0.157    -6.266     0       0.0413  145.036
#
#    valence  music_genre
# 0    0.759            5
# 1    0.531            5
# 2    0.333            5
# 3    0.270            5
# 4    0.323            5

# %%
music.dtypes
# Out:
# popularity          float64
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# speechiness         float64
# tempo               float64
# valence             float64
# music_genre           int64
# dtype: object

# %% [markdown]
# ## Preprocessing
#
# Preprocessing involves preparing the dataset for modelling. Labels are separated from features; the latter are scaled; both sets are split into training, validation, and testing data.

# %%
# Separate labels
music_features = music.drop("music_genre", axis = 1)
music_labels = music["music_genre"]
# Scale features
#scaler = StandardScaler() # Instance of StandarScaler() 
#music_features_scaled = scaler.fit_transform(music_features)
#music_features_scaled.mean(), music_features_scaled.std()
#StandardScaler() handles datasets with outliers. 
#It makes all values centered around 0 with standard deviation of 1.

# %%
#The data are split into train, validation, and test set. 
#The algorithm is trained on the former, validated - on the second, and tested - on the latter. 
#A tiny portion is allocated for testing. 
#The same number of samples were set aside for validation. 


tr_val_f, test_features, tr_val_l, test_labels = train_test_split(music_features, music_labels, test_size = 0.1, stratify = music_labels)

train_features, val_features, train_labels, val_labels = train_test_split(tr_val_f, tr_val_l, test_size = len(test_labels), stratify = tr_val_l)

train_features.shape, train_labels.shape, val_features.shape, val_labels.shape, test_features.shape, test_labels.shape
# Out:
# ((36016, 13), (36016,), (4502, 13), (4502,), (4502, 13), (4502,))

# %%
train_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36016 entries, 13954 to 48558
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   popularity        36016 non-null  float64
#  1   acousticness      36016 non-null  float64
#  2   danceability      36016 non-null  float64
#  3   duration_ms       36016 non-null  float64
#  4   energy            36016 non-null  float64
#  5   instrumentalness  36016 non-null  float64
#  6   key               36016 non-null  int64
#  7   liveness          36016 non-null  float64
#  8   loudness          36016 non-null  float64
#  9   mode              36016 non-null  int64
#  10  speechiness       36016 non-null  float64
#  11  tempo             36016 non-null  float64
#  12  valence           36016 non-null  float64
# dtypes: float64(11), int64(2)
# memory usage: 3.8 MB

# %%
train_labels
# Out:
# 13954    7
# 41454    3
# 7104     1
# 35694    9
# 40231    3
#         ..
# 48255    6
# 26032    8
# 14053    7
# 41912    3
# 48558    6
# Name: music_genre, Length: 36016, dtype: int64

# %%
val_features
# Out:
#        popularity  acousticness  danceability  duration_ms  energy  \
# 18459        52.0      0.181000         0.766     201362.0   0.664
# 14740        45.0      0.504000         0.513     270320.0   0.767
# 13868        35.0      0.549000         0.711     376440.0   0.247
# 31059        27.0      0.964000         0.450     292800.0   0.130
# 2101         46.0      0.000587         0.619     256213.0   0.873
# ...           ...           ...           ...          ...     ...
# 18487        63.0      0.771000         0.704     133560.0   0.478
# 30913        37.0      0.484000         0.666     259245.0   0.295
# 32603        36.0      0.432000         0.545     173466.0   0.582
# 22862        50.0      0.011100         0.587     213387.0   0.797
# 33886        25.0      0.566000         0.677     216227.0   0.140
#
#        instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 18459          0.000008    2    0.1380    -4.171     0       0.1210  145.054
# 14740          0.000000    5    0.1260    -5.966     1       0.0945  116.412
# 13868          0.000235   10    0.1660   -12.586     0       0.0320   92.276
# 31059          0.142000   10    0.1220   -17.074     0       0.0388   74.935
# 2101           0.375000    7    0.2590    -9.529     1       0.0439  128.309
# ...                 ...  ...       ...       ...   ...          ...      ...
# 18487          0.000516    0    0.0875    -6.562     0       0.0470  128.789
# 30913          0.002590    3    0.1110    -9.040     1       0.0319  123.972
# 32603          0.120000    8    0.7380   -12.656     0       0.0764  119.295
# 22862          0.000078    3    0.0851    -5.671     0       0.0429  147.905
# 33886          0.887000    5    0.0909   -21.661     0       0.0435  119.092
#
#        valence
# 18459    0.584
# 14740    0.598
# 13868    0.502
# 31059    0.269
# 2101     0.430
# ...        ...
# 18487    0.420
# 30913    0.280
# 32603    0.561
# 22862    0.440
# 33886    0.467
#
# [4502 rows x 13 columns]

# %%
val_labels
# Out:
# 18459    0
# 14740    7
# 13868    7
# 31059    2
# 2101     5
#         ..
# 18487    0
# 30913    2
# 32603    2
# 22862    4
# 33886    2
# Name: music_genre, Length: 4502, dtype: int64

# %%
test_features
# Out:
#        popularity  acousticness  danceability  duration_ms   energy  \
# 9057         17.0        0.0305         0.589     195000.0  0.90100
# 7921         22.0        0.2600         0.697     127333.0  0.47400
# 7775         22.0        0.0145         0.511     253227.0  0.90500
# 11368        42.0        0.9640         0.750      89006.0  0.12600
# 32683        26.0        0.7370         0.345     189173.0  0.32900
# ...           ...           ...           ...          ...      ...
# 32151        52.0        0.6370         0.342     240547.0  0.33100
# 41135        29.0        0.9150         0.181     198773.0  0.04330
# 38205        60.0        0.2180         0.534     374653.0  0.41400
# 42437        29.0        0.9950         0.487         -1.0  0.00188
# 27513        68.0        0.5600         0.644     240440.0  0.69700
#
#        instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 9057           0.000147   10    0.1070    -2.017     0       0.0954  130.009
# 7921           0.870000    3    0.0822    -9.976     0       0.0327  119.998
# 7775           0.000000    8    0.8000    -3.945     0       0.0643  174.040
# 11368          0.949000    6    0.1090   -12.691     1       0.1370   51.998
# 32683          0.470000    3    0.0961   -10.898     0       0.0323  168.010
# ...                 ...  ...       ...       ...   ...          ...      ...
# 32151          0.000000    3    0.1050    -8.884     0       0.0287  130.859
# 41135          0.849000    0    0.1170   -25.125     1       0.0449   75.655
# 38205          0.000002    5    0.1030    -7.952     0       0.0403  117.079
# 42437          0.960000    8    0.0707   -40.027     0       0.1330  124.782
# 27513          0.000000    3    0.1110    -6.069     1       0.0542  120.044
#
#        valence
# 9057     0.761
# 7921     0.495
# 7775     0.349
# 11368    0.278
# 32683    0.284
# ...        ...
# 32151    0.106
# 41135    0.108
# 38205    0.458
# 42437    0.138
# 27513    0.244
#
# [4502 rows x 13 columns]

# %%
test_labels
# Out:
# 9057     1
# 7921     1
# 7775     1
# 11368    7
# 32683    2
#         ..
# 32151    2
# 41135    3
# 38205    9
# 42437    3
# 27513    8
# Name: music_genre, Length: 4502, dtype: int64

# %% [markdown]
# ## Modelling
# ![Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%2012.51.00%20p.%C2%A0m..png](attachment:Captura%20de%20Pantalla%202022-10-27%20a%20la%28s%29%2012.51.00%20p.%C2%A0m..png)

# %% [markdown]
# ### Logistic Regression

# %%
lr = LogisticRegression()
model_logistic = lr.fit(train_features, np.ravel(train_labels))

# %% [markdown]
# ### XGBoost

# %%
import xgboost as xgb

xgb_model = xgb.XGBClassifier(random_state = 0)
xgb_model.fit(train_features,train_labels)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#               grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_bin=256, max_cat_threshold=64, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', ...)

# %% [markdown]
# ## Accuracy and f1 score

# %% [markdown]
# ### Logistic Regression

# %%
accuracy = model_logistic.score(test_features, test_labels)
print("Accuracy is {}".format(accuracy))
# Out:
# Accuracy is 0.20613060861839183

# %% [markdown]
# ### XGBoots

# %%
accuracy = xgb_model.score(test_features, test_labels)
print("Accuracy is {}".format(accuracy))
# Out:
# Accuracy is 0.573745002221235

# %% [markdown]
# ## Classification report

# %% [markdown]
# ### Logistic Regression

# %%
print(classification_report(test_labels, model_logistic.predict(test_features)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       449
#            1       0.33      0.41      0.37       450
#            2       0.00      0.00      0.00       447
#            3       0.33      0.41      0.36       450
#            4       0.18      0.14      0.15       449
#            5       0.15      0.18      0.17       447
#            6       0.00      0.00      0.00       452
#            7       0.14      0.13      0.14       452
#            8       0.16      0.39      0.23       450
#            9       0.18      0.40      0.25       456
#
#     accuracy                           0.21      4502
#    macro avg       0.15      0.21      0.17      4502
# weighted avg       0.15      0.21      0.17      4502
# /Users/andrescarvajal/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/andrescarvajal/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/andrescarvajal/opt/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### XGBoots

# %%
print(classification_report(test_labels, xgb_model.predict(test_features)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.42      0.40      0.41       449
#            1       0.82      0.74      0.78       450
#            2       0.61      0.54      0.57       447
#            3       0.86      0.85      0.85       450
#            4       0.59      0.59      0.59       449
#            5       0.68      0.63      0.65       447
#            6       0.37      0.38      0.37       452
#            7       0.59      0.57      0.58       452
#            8       0.32      0.32      0.32       450
#            9       0.54      0.71      0.61       456
#
#     accuracy                           0.57      4502
#    macro avg       0.58      0.57      0.57      4502
# weighted avg       0.58      0.57      0.57      4502

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# ### Logistic Regression

# %%
plt.figure(figsize = (8, 6))
sns.heatmap(confusion_matrix(test_labels, model_logistic.predict(test_features)),
    annot = True,
    fmt = ".0f",
    cmap = "vlag",
    linewidths = 2,
    linecolor = "red",
    xticklabels = model_logistic.classes_,
    yticklabels = model_logistic.classes_)
plt.title("Actual values")
plt.ylabel("Predicted values")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### XGBoots

# %%
plt.figure(figsize = (8, 6))
sns.heatmap(confusion_matrix(test_labels, xgb_model.predict(test_features)),
    annot = True,
    fmt = ".0f",
    cmap = "vlag",
    linewidths = 2,
    linecolor = "red",
    xticklabels = xgb_model.classes_,
    yticklabels = xgb_model.classes_)
plt.title("Actual values")
plt.ylabel("Predicted values")
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  Feature importance

# %% [markdown]
# ### Logistic Regression

# %%
model_logistic.fit(test_features,test_labels)
importance = model_logistic.coef_[0]
#importance is a list so you can plot it. 
feat_importances = pd.Series(importance)
feat_importances.plot(kind='barh',title = 'Feature Importance')

feature_importance = pd.DataFrame(feature_names, columns = ["feature"])
feature_importance["importance"] = pow(math.e, w)
feature_importance = feature_importance.sort_values(by = ["importance"], ascending=False)
 
from sklearn.linear_model import LogisticRegression
ax = feature_importance.plot.barh(x='feature', y='importance')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/pd/gd_w9jbx5hb006vr17f17dmw0000gn/T/ipykernel_37476/1696145186.py in <module>
#       5 feat_importances.plot(kind='barh',title = 'Feature Importance')
#       6
# ----> 7 feature_importance = pd.DataFrame(feature_names, columns = ["feature"])
#       8 feature_importance["importance"] = pow(math.e, w)
#       9 feature_importance = feature_importance.sort_values(by = ["importance"], ascending=False)
#
# NameError: name 'feature_names' is not defined

# %% [markdown]
# ### XGBoots

# %%
xgb_model.feature_importances_
feat_importances = pd.Series(xgb_model.feature_importances_)
feat_importances.plot(kind='barh',title = 'Feature Importance')
# Out:
# <AxesSubplot:title={'center':'Feature Importance'}>

# %% [markdown]
# ## ROC curve

# %% [markdown]
# ### Logistic Regression

# %%
predicted_labels = model_logistic.predict_proba(test_features)

# %%
roc_auc_score(test_labels, predicted_labels, multi_class = "ovr")
# Out:
# 0.6509386163166067

# %%
skplt.metrics.plot_roc(test_labels, predicted_labels)
plt.show()

# %% [markdown]
# ### XGBoots

# %%
predicted_labels = model_logistic.predict_proba(test_features)

# %%
roc_auc_score(test_labels, predicted_labels, multi_class = "ovr")
# Out:
# 0.6509386163166067

# %%
skplt.metrics.plot_roc(test_labels, predicted_labels)
plt.show()

# %% [markdown]
# # SHAP

# %% [markdown]
# ### Logistic Regression

# %%
import shap

# %%
explainer = shap.Explainer(model_logistic.predict,test_features)
shap_values = explainer(test_features)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])
# Out:
# Permutation explainer: 4503it [05:20, 13.70it/s]

# %%
shap.plots.beeswarm(shap_values)

# %% [markdown]
# ### XGBoots

# %%
explainer = shap.Explainer(model_logistic.predict,test_features)
shap_values = explainer(test_features)

# visualize the first prediction's explanation
shap.plots.waterfall(shap_values[0])
# Out:
# Permutation explainer: 4503it [07:01, 10.37it/s]

# %%
shap.plots.beeswarm(shap_values)
